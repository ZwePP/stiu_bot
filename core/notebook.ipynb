# %% [markdown]
# ### Loading PDF and Removing /n

# %%
file_path = "../data/ug_student_handbook.pdf"

# %%
from langchain_community.document_loaders import PyPDFLoader
import pprint
loader = PyPDFLoader(file_path)

# %%
pages_pdf = loader.load()

# %%
#Removing \n in pages
for page in pages_pdf:
    page.page_content = ' '.join(page.page_content.split())

# %% [markdown]
# ### Document Splitting with Recusrive CharacterTextSplitter

# %%
import uuid
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap =50
)

# %%
texts = text_splitter.split_documents(pages_pdf)

# %%
#metadata list only
metadata_list = [text.metadata for text in texts]

# %%
#id_list
id_list = [str(uuid.uuid4()) for _ in texts]

# %%
id_list
# Out:
# ['356ea3db-e2e4-4475-ae04-6ba18c1ad5f3',
#  'b0e84474-3640-4704-888e-ada433e56572',
#  'a7b1261a-41ba-4cd1-8d8a-596ae9f61ffd',
#  '42c32110-b5dc-4f07-8f48-930ef49b39cf',
#  'd6f2baac-198d-4a81-9f62-b113f53e5fa9',
#  '17409e67-72c5-461b-af96-25ea17ddcc42',
#  '65323618-9f5f-40c5-a837-c5fbbcb87959',
#  '25505394-ec0c-4e48-a99e-2eff4683eeee',
#  '4b6bee28-2c09-43f6-b05f-35293b267391',
#  '935d5383-204e-45bf-8bb3-297d128a83b7',
#  '21ce8945-c069-44d7-96d7-fbad1b84d9ec',
#  'b7318ee1-8833-4e36-b5ea-bd1ed7656b20',
#  '81355d01-efb1-46a0-9664-b4e046f51c5d',
#  '5535679b-3e29-477e-9905-baa9fd909cf8',
#  '8864efe9-89fe-4c41-b276-eab1c90588ec',
#  '907a3b9d-525d-4c78-ad04-7ce67e20a8d7',
#  '13cd7d9b-8e46-4b86-8029-36ce9843db21',
#  'fc170a58-1acd-4fa0-828a-f0c3bc69d12e',
#  '8d5e0a3f-a108-467f-b4da-5f5936854d30',
#  '5cfecda9-4bff-4e71-9e5b-55c27ca53fa8',
#  '688e1fe7-9187-4d67-bc7a-344f2ed657bb',
#  'ba94bd4e-8de0-48e9-92ba-3cdae40020b1',
#  '7013404d-a6bd-49f4-92ac-394548c34d72',
#  '07be42b3-e06c-4128-bbea-088719890115',
#  '357dcb8b-8a70-43fe-b8e4-5e6ab878e329',
#  '7f9cc37c-269a-4e7d-97d7-11daa7584d91',
#  '9f910770-9e6d-48f1-8c6e-558284408b08',
#  '0df9b1d9-359a-4656-96d0-c59717431e1a',
#  '4348493b-609e-417e-8026-5f4f8f464ffc',
#  '8edb01b2-76c5-4de9-9b82-9f43b3a02dd6',
#  'a6fbc95a-a255-4e15-a5fe-9af46f09c878',
#  'fd2b67a5-9071-4428-9173-270afe115e7e',
#  'a0c12a69-5ad3-45df-8e04-21dab246c906',
#  'dedec239-cc3d-4402-acf7-6b2b3b7748ef',
#  '9f7c237a-7c4b-4ef9-bc82-8e0143d70a91',
#  'd57559c0-917c-40f2-85da-a6ff2174f2fd',
#  '097dff5b-15f1-47b0-9a95-f134331418df',
#  '932033b6-c1d4-45fc-99d2-fd2c45db9e67',
#  '7bc0c556-91d8-4797-a247-61666485f190',
#  '85e2598b-7754-455d-a9e6-b41ab60ab5ba',
#  'ff696bb1-bd7c-4f75-8fd4-baa1963952ef',
#  'dc2f834f-01c0-4056-9618-2846df923f33',
#  'c681ae42-6f66-46e2-a522-db1066dea378',
#  '7a763b2c-0757-4d35-8662-9d4c25f81bed',
#  'e9b402e1-bed8-4d85-9829-f5d6c84f3666',
#  '5ba391e6-78a4-467b-8820-e7a40b16c320',
#  'eb0c98ed-8751-42b0-9e3f-aca5db98c3ce',
#  'f69c5799-88cd-4505-b60b-0a0bec9d8766',
#  '27567c70-e09f-4d54-b70a-465f2b90d26b',
#  'ca6fc587-a904-4459-ac2a-0e1258463753',
#  '09d6d858-7beb-49cd-9b6d-b1257f2b48b8',
#  'feea31ae-07b9-44c4-a962-f8c918dbddfd',
#  'e45f4837-8294-4dae-befa-71eb5f705111',
#  '1d693ae9-fbee-49f2-8116-1055f20d12d9',
#  '03f8af73-8235-4e18-91ee-625017fb9da9',
#  '5d33dc2c-a599-4afd-82ff-a76132f3dd3e',
#  'ba046c5c-2acd-484c-8029-853cd408e15a',
#  'ded5ed08-f5a6-4078-b6e6-12088ffb3aa1',
#  'a8d451af-0d93-48ff-a842-5b41edc7f17e',
#  '975de955-717e-4bb5-9fc8-67d3347e7292',
#  '12cafd55-cf00-4bfc-9cc0-91496d9598f1',
#  '4d297c96-95f1-4d35-a905-d3f853d98768',
#  'd2ea8e22-ee02-413c-b61f-f27813a05046',
#  '9ca6c5b4-5bf6-42b2-9189-1aed530f054f',
#  '72481653-76dc-42c4-9cb6-55a501dc8675',
#  'efaa4003-7441-4bef-b37a-900c6a73461b',
#  'eab1ec61-2482-4389-8420-08e1478b4b05',
#  '39811e1b-e11c-4826-8095-8f6e08bc9287',
#  'd26ebafa-1f2a-4c34-b113-da6b02af78c2',
#  '6501a6dd-01fb-4b0d-882d-7d65de7b3e67',
#  'ad4eee85-255f-4179-b2a3-106619a8e011',
#  '3ad4c976-b9ed-4df3-8eed-6ce972d4fd35',
#  '06115d5b-9c35-4e9f-bf41-7d02054c412c',
#  'ab6ae3c2-7dcd-4b1e-8dc7-5d40b3eadc2a',
#  '0e57dcb8-6d1f-4a79-9361-b15aa0d8fac1',
#  '3164f8af-f8ee-42fc-a16d-e8e7f74dc784',
#  '3ec5e2ad-f4f2-46fb-a7e0-3df6b8f7b945',
#  'ccc2c3e6-0669-4711-bb4e-55baa4e9fafd',
#  '88e78470-a0ec-4a00-b7c1-d705f6c8e888',
#  'c14c88d0-e191-467d-af0d-5609d54ba442',
#  '6e43cc4b-e2fd-414f-8c48-45bf98b4306d',
#  '33213e2e-417e-4b00-baa4-135d3c611963',
#  'b9f3c2d1-154f-48d1-9060-47ebcc91453e',
#  '29aebb70-4acf-4d2f-800a-e323ff522b58',
#  'c58408ee-30b9-486a-b5e5-7f56e71e42b2',
#  'a3ed003e-77e2-4be1-84b9-9ddb8179a3f3']

# %% [markdown]
# ### Embedding

# %% [markdown]
# changing text -> vectors

# %%
from sentence_transformers import SentenceTransformer

# %%
embedding = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
#Storing all the content in a list
page_contents = []
for text in texts:
    page_contents.append(text.page_content)

# %%
#Encode all the content into list of vectors
page_contents_vectors = [embedding.encode(content) for content in page_contents]

# %%
(len(page_contents_vectors),len(id_list), len(metadata_list))
# Out:
# (229, 229, 229)

# %% [markdown]
# ### Chroma DB

# %%
import chromadb

chroma_client = chromadb.PersistentClient(path="./chroma_langchain_db")

# %%
collection = chroma_client.get_or_create_collection(name="handbook_embeddings_collections")

# %%
collection.add(
    documents=page_contents,
    embeddings=page_contents_vectors,
    ids=id_list,
    metadatas=metadata_list
)

# %% [markdown]
# ### Retrieving Query

# %%
query_text = "School Uniform?"

# %%
query_vector = embedding.encode(query_text)

# %%
result = collection.query(
    query_embeddings=query_vector,
    n_results=3
)

# %%
result['documents']
# Out:
# [['7. Shoes Black covered shoes Student Uniform and Dress Code for male 1. Blazer Gray color 2. Shirt White shirt, short sleeves, button down 3. Trousers Plain black according to the university pattern 4. Necktie University pattern 5. Pin University emblem, on the necktie 6. Belt University emblem buckle, black leather belt 7. Socks Formal black color 8. Shoes Black covered shoes',
#   'you are and the character you possess. Stamford International University has a formal uniform. It exists in two versions, one for men and one for women (applicable for undergraduate): Student Uniform and Dress Code for female 1. Blazer Gray color 2. Shirt White shirt, short sleeves, button down 3. Button University emblem 4. Skirt Gray color, knee length 5. Pin University emblem, right side 6. Belt University emblem buckle, black leather belt 7. Shoes Black covered shoes Student Uniform and',
#   'students can expect to go on many company visits and to give presentations in front of senior members of companies. As such, when representing the university in such situations , students are expected to dress in business casual attire or wear their full student uniform. You are requested to take it upon yourself that when you wear the University uniform, you wear it appropriately and with pride. The way you groom yourself reflects the person you are and the character you possess. Stamford']]

# %%
pprint.pp(result)
# Out:
# {'ids': [['3390f3a6-8d5e-4dc7-8761-7b17b0109ebb',
#           '78f7a13b-1313-4f03-9ab9-4a822c414a39',
#           'f2aeb4d5-0ce0-4363-8a35-2a3b570c7d74']],
#  'embeddings': None,
#  'documents': [['7. Shoes Black covered shoes Student Uniform and Dress Code '
#                 'for male 1. Blazer Gray color 2. Shirt White shirt, short '
#                 'sleeves, button down 3. Trousers Plain black according to the '
#                 'university pattern 4. Necktie University pattern 5. Pin '
#                 'University emblem, on the necktie 6. Belt University emblem '
#                 'buckle, black leather belt 7. Socks Formal black color 8. '
#                 'Shoes Black covered shoes',
#                 'you are and the character you possess. Stamford International '
#                 'University has a formal uniform. It exists in two versions, '
#                 'one for men and one for women (applicable for undergraduate): '
#                 'Student Uniform and Dress Code for female 1. Blazer Gray '
#                 'color 2. Shirt White shirt, short sleeves, button down 3. '
#                 'Button University emblem 4. Skirt Gray color, knee length 5. '
#                 'Pin University emblem, right side 6. Belt University emblem '
#                 'buckle, black leather belt 7. Shoes Black covered shoes '
#                 'Student Uniform and',
#                 'students can expect to go on many company visits and to give '
#                 'presentations in front of senior members of companies. As '
#                 'such, when representing the university in such situations , '
#                 'students are expected to dress in business casual attire or '
#                 'wear their full student uniform. You are requested to take it '
#                 'upon yourself that when you wear the University uniform, you '
#                 'wear it appropriately and with pride. The way you groom '
#                 'yourself reflects the person you are and the character you '
#                 'possess. Stamford']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'source': 'D:\\2025GRIND\\student_handbook_chatbot\\data\\ug_student_handbook.pdf',
#                  'total_pages': 43,
#                  'creator': 'Microsoft® Word for Microsoft 365',
#                  'author': 'Colin Pinto',
#                  'page': 18,
#                  'page_label': '19',
#                  'moddate': '2025-11-12T15:33:43+07:00',
#                  'creationdate': '2025-11-12T15:33:43+07:00',
#                  'producer': 'Microsoft® Word for Microsoft 365'},
#                 {'author': 'Colin Pinto',
#                  'page': 18,
#                  'creationdate': '2025-11-12T15:33:43+07:00',
#                  'source': 'D:\\2025GRIND\\student_handbook_chatbot\\data\\ug_student_handbook.pdf',
#                  'moddate': '2025-11-12T15:33:43+07:00',
#                  'total_pages': 43,
#                  'creator': 'Microsoft® Word for Microsoft 365',
#                  'page_label': '19',
#                  'producer': 'Microsoft® Word for Microsoft 365'},
#                 {'page': 18,
#                  'author': 'Colin Pinto',
#                  'producer': 'Microsoft® Word for Microsoft 365',
#                  'moddate': '2025-11-12T15:33:43+07:00',
#                  'source': 'D:\\2025GRIND\\student_handbook_chatbot\\data\\ug_student_handbook.pdf',
#                  'total_pages': 43,
#                  'page_label': '19',
#                  'creationdate': '2025-11-12T15:33:43+07:00',
#                  'creator': 'Microsoft® Word for Microsoft 365'}]],
#  'distances': [[0.7878217697143555, 0.7903684973716736, 0.8646990060806274]]}

# %% [markdown]
# validate context

# %%
for i, doc in enumerate(result["documents"][0]):
    print(f"\n--- Result {i+1} ---\n")
    print(doc[:1000])
# Out:
# --- Result 1 ---
#
# 7. Shoes Black covered shoes Student Uniform and Dress Code for male 1. Blazer Gray color 2. Shirt White shirt, short sleeves, button down 3. Trousers Plain black according to the university pattern 4. Necktie University pattern 5. Pin University emblem, on the necktie 6. Belt University emblem buckle, black leather belt 7. Socks Formal black color 8. Shoes Black covered shoes
#
# --- Result 2 ---
#
# you are and the character you possess. Stamford International University has a formal uniform. It exists in two versions, one for men and one for women (applicable for undergraduate): Student Uniform and Dress Code for female 1. Blazer Gray color 2. Shirt White shirt, short sleeves, button down 3. Button University emblem 4. Skirt Gray color, knee length 5. Pin University emblem, right side 6. Belt University emblem buckle, black leather belt 7. Shoes Black covered shoes Student Uniform and
#
# --- Result 3 ---
#
# students can expect to go on many company visits and to give presentations in front of senior members of companies. As such, when representing the university in such situations , students are expected to dress in business casual attire or wear their full student uniform. You are requested to take it upon yourself that when you wear the University uniform, you wear it appropriately and with pride. The way you groom yourself reflects the person you are and the character you possess. Stamford

# %% [markdown]
# ### Ollama

# %%
from ollama import chat
from ollama import ChatResponse

# %%
response = chat(
    model='mistral',
    messages=[{'role': 'user', 'content': 'Hello!'}],
)
print(response.message.content)
# Out:
#  Hello there! How can I help you today? Is there something specific you'd like to know or talk about? I'm here to assist with a wide range of topics, from answering questions and providing explanations to engaging in conversation and even helping with writing tasks. What do you need help with?
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
